# %%
import bs4 as bs
import pickle
import requests
import datetime as dt
import os
import pandas as pd
import pandas_datareader as web
from tqdm import tqdm
from time import sleep

tickers_file= "sp500tickers.pickle"
data_dir = 'stock_dfs'

def save_sp500_tickers():
    url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    resp = requests.get(url)
    soup = bs.BeautifulSoup(resp.text, 'lxml')
    table = soup.find('table', {'class':'wikitable sortable'})
    tickers = []
    for row in table.findAll('tr')[1:]:
        ticker = row.findAll('td')[0].text
        tickers.append(ticker)
    with open(tickers_file, "wb") as f:
        pickle.dump(tickers, f)
    print(tickers)
    return tickers

#save_sp500_tickers()

# %%
def get_data_from_yahoo(reload_sp500=False):
    if reload_sp500:
        tickers=save_sp500_tickers()
    else:
        with open(tickers_file, "rb") as f:
            tickers = pickle.load(f)
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
    start = dt.datetime(2000,1,1)
    end = dt.datetime(2017,12,28)
    
    for ticker in tqdm(tickers):
        if not os.path.exists(os.path.join(data_dir, ticker + '.csv')):
            if (ticker.endswith('.B')):
                continue 
            print('Fetching {}'.format(ticker))
            try:
                df = web.DataReader(ticker, 'yahoo', start, end, retry_count=10)
                df.to_csv(os.path.join('stock_dfs', ticker + '.csv'))
            except web.base.RemoteDataError as e:
                print('DataReader Remote Data Exception:', e)
        else:
            #print('Already have {}'.format(ticker))
            pass
        
print(web.__version__)  
get_data_from_yahoo()
# Out:
#   0%|          | 0/505 [00:00<?, ?it/s]
# 0.5.0
# Fetching MS
#  64%|██████▍   | 324/505 [00:15<00:08, 21.60it/s]
# Fetching NAVI
#  65%|██████▌   | 330/505 [00:16<00:08, 20.27it/s]
# Fetching NBL
#  68%|██████▊   | 342/505 [00:17<00:08, 19.05it/s]
# Fetching NCLH
#  69%|██████▊   | 347/505 [00:19<00:08, 17.95it/s]
# Fetching ORLY
#  70%|██████▉   | 351/505 [00:22<00:09, 15.65it/s]
# Fetching OXY
#  70%|██████▉   | 352/505 [00:24<00:10, 14.44it/s]
# Fetching OMC
#  70%|██████▉   | 353/505 [00:25<00:11, 13.60it/s]
# Fetching PCAR
#  70%|███████   | 356/505 [00:27<00:11, 12.91it/s]
# Fetching PNR
#  72%|███████▏  | 362/505 [00:29<00:11, 12.41it/s]
# Fetching PKI
#  72%|███████▏  | 365/505 [00:46<00:17,  7.79it/s]
# DataReader Remote Data Exception: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/PKI?period1=946713600&period2=1514534399&interval=1d&events=history&crumb=.i%5Cu002F1fvYv6YY
# Fetching PNW
#  73%|███████▎  | 371/505 [01:09<00:25,  5.35it/s]
# DataReader Remote Data Exception: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/PNW?period1=946713600&period2=1514534399&interval=1d&events=history&crumb=9w%5Cu002Fp.wiH%5Cu002FvL
# Fetching PPL
#  74%|███████▍  | 376/505 [01:12<00:24,  5.17it/s]
# Fetching PEG
#  76%|███████▌  | 384/505 [01:15<00:23,  5.09it/s]
# Fetching PVH
#  77%|███████▋  | 387/505 [01:17<00:23,  4.97it/s]
# Fetching QCOM
#  77%|███████▋  | 390/505 [01:21<00:23,  4.80it/s]
# Fetching ROP
#  80%|████████  | 405/505 [01:25<00:21,  4.74it/s]
# Fetching SCG
#  81%|████████  | 410/505 [01:43<00:23,  3.97it/s]
# DataReader Remote Data Exception: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/SCG?period1=946713600&period2=1514534399&interval=1d&events=history&crumb=klijpdL%5Cu002F.p.
# Fetching SO
#  84%|████████▎ | 422/505 [01:44<00:20,  4.03it/s]
# Fetching SYK
#  85%|████████▍ | 429/505 [01:46<00:18,  4.04it/s]
# Fetching SYY
#  86%|████████▌ | 434/505 [01:47<00:17,  4.04it/s]
# Fetching TROW
#  86%|████████▌ | 435/505 [01:48<00:17,  4.00it/s]
# Fetching TGT
#  87%|████████▋ | 437/505 [01:50<00:17,  3.96it/s]
# Fetching TXT
#  87%|████████▋ | 441/505 [01:51<00:16,  3.95it/s]
# Fetching TSS
#  89%|████████▊ | 447/505 [01:53<00:14,  3.94it/s]
# Fetching TDG
#  89%|████████▉ | 449/505 [01:54<00:14,  3.91it/s]
# Fetching USB
#  90%|█████████ | 457/505 [02:12<00:13,  3.44it/s]
# DataReader Remote Data Exception: Unable to read URL: https://query1.finance.yahoo.com/v7/finance/download/USB?period1=946713600&period2=1514534399&interval=1d&events=history&crumb=eGRzQF%5Cu002F3n00
# Fetching UNP
#  91%|█████████ | 460/505 [02:14<00:13,  3.43it/s]
# Fetching VTR
#  93%|█████████▎| 471/505 [02:15<00:09,  3.47it/s]
# Fetching WRK
#  97%|█████████▋| 490/505 [02:17<00:04,  3.58it/s]
# Fetching WYN
#  98%|█████████▊| 495/505 [02:18<00:02,  3.58it/s]
# Fetching ZBH
# 100%|██████████| 505/505 [02:20<00:00,  3.61it/s]

# %%
def compile_data():
    with open(tickers_file, 'rb') as f:
        tickers = pickle.load(f)
        
    main_df = pd.DataFrame()
    
    for count, ticker in enumerate(tickers[:50]):
        df = pd.read_csv(os.path.join(data_dir, ticker + ".csv"))
        df.set_index('Date', inplace=True)
        df.rename(columns= {'Adj Close': ticker}, inplace=True)
        df.drop(['Open', 'High', 'Low', 'Close', 'Volume'], 1, inplace=True)
        
        if main_df.empty:
            main_df = df
        else:
            main_df = main_df.join(df, how='outer')
        
        if count % 10 == 0:
            print(count)

    print(main_df.head())
    main_df.to_csv('sp500_joined_closes.csv')

compile_data()

# %%
import glob
import mysql.connector as connector
config = {
   'user': 'jameschl',
   'password': '123456',
   'database': 'yahoo',
   'host': '127.0.0.1'
}
conn = connector.connect(**config)
c = conn.cursor()
def create_table(ticker, c):
    table_name = ticker + 'Staging'
    c.execute('create table ' + table_name + 
              """(Date date, 
               Open float, 
               High float, 
               Low float, 
               Close float, 
               Adj_Close float, 
               Volume float )""", )
    
def insert_row(filename, ticker, c):
    print('insert row')
    delimiter = r','
    dateString = r'%d-%b-%Y'
    table_name = ticker + 'Staging'
    c.execute("Load data local infile %s into table " + table_name + 
              " fields terminated by %s ignore 1 lines" +
             "(Date,Open,High,Low,Close,Adj_Close,Volume)",
             (filename, delimiter))
    print('load file', filename, 'into', table_name)

# %%
def insert_db():
    for f in glob.glob(data_dir + '/*'):
        if (f.endswith('.csv')):
            ticker = f.split('/')[1].split('.')[0]
            print('ticker', ticker)
            try:
                create_table(ticker, c)
                insert_row(f, ticker, c)
                print('load file', f, 'into database')
            except Exception as e:
                print(e)
    conn.commit()
    c.close()
    conn.close()

# %%
insert_db()
# Out:
# ticker A
# 1050 (42S01): Table 'astaging' already exists
# ticker AAL
# 1050 (42S01): Table 'aalstaging' already exists
# ticker AAP
# 1050 (42S01): Table 'aapstaging' already exists
# ticker AAPL
# 1050 (42S01): Table 'aaplstaging' already exists
# ticker ABBV
# 1050 (42S01): Table 'abbvstaging' already exists
# ticker ABC
# 1050 (42S01): Table 'abcstaging' already exists
# ticker ABT
# 1050 (42S01): Table 'abtstaging' already exists
# ticker ACN
# 1050 (42S01): Table 'acnstaging' already exists
# ticker ADBE
# 1050 (42S01): Table 'adbestaging' already exists
# ticker ADI
# 1050 (42S01): Table 'adistaging' already exists
# ticker ADM
# 1050 (42S01): Table 'admstaging' already exists
# ticker ADP
# 1050 (42S01): Table 'adpstaging' already exists
# ticker ADS
# 1050 (42S01): Table 'adsstaging' already exists
# ticker ADSK
# 1050 (42S01): Table 'adskstaging' already exists
# ticker AEE
# 1050 (42S01): Table 'aeestaging' already exists
# ticker AEP
# 1050 (42S01): Table 'aepstaging' already exists
# ticker AES
# 1050 (42S01): Table 'aesstaging' already exists
# ticker AET
# 1050 (42S01): Table 'aetstaging' already exists
# ticker AFL
# 1050 (42S01): Table 'aflstaging' already exists
# ticker AGN
# 1050 (42S01): Table 'agnstaging' already exists
# ticker AIG
# 1050 (42S01): Table 'aigstaging' already exists
# ticker AIV
# 1050 (42S01): Table 'aivstaging' already exists
# ticker AIZ
# 1050 (42S01): Table 'aizstaging' already exists
# ticker AJG
# 1050 (42S01): Table 'ajgstaging' already exists
# ticker AKAM
# 1050 (42S01): Table 'akamstaging' already exists
# ticker ALB
# 1050 (42S01): Table 'albstaging' already exists
# ticker ALGN
# 1050 (42S01): Table 'algnstaging' already exists
# ticker ALK
# 1050 (42S01): Table 'alkstaging' already exists
# ticker ALL
# 1050 (42S01): Table 'allstaging' already exists
# ticker ALLE
# 1050 (42S01): Table 'allestaging' already exists
# ticker ALXN
# 1050 (42S01): Table 'alxnstaging' already exists
# ticker AMAT
# 1050 (42S01): Table 'amatstaging' already exists
# ticker AMD
# 1050 (42S01): Table 'amdstaging' already exists
# ticker AME
# 1050 (42S01): Table 'amestaging' already exists
# ticker AMG
# 1050 (42S01): Table 'amgstaging' already exists
# ticker AMGN
# 1050 (42S01): Table 'amgnstaging' already exists
# ticker AMP
# 1050 (42S01): Table 'ampstaging' already exists
# ticker AMT
# 1050 (42S01): Table 'amtstaging' already exists
# ticker AMZN
# 1050 (42S01): Table 'amznstaging' already exists
# ticker ANDV
# 1050 (42S01): Table 'andvstaging' already exists
# ticker ANSS
# 1050 (42S01): Table 'anssstaging' already exists
# ticker ANTM
# 1050 (42S01): Table 'antmstaging' already exists
# ticker AON
# 1050 (42S01): Table 'aonstaging' already exists
# ticker AOS
# 1050 (42S01): Table 'aosstaging' already exists
# ticker APA
# 1050 (42S01): Table 'apastaging' already exists
# ticker APC
# 1050 (42S01): Table 'apcstaging' already exists
# ticker APD
# 1050 (42S01): Table 'apdstaging' already exists
# ticker APH
# 1050 (42S01): Table 'aphstaging' already exists
# ticker APTV
# 1050 (42S01): Table 'aptvstaging' already exists
# ticker ARE
# 1050 (42S01): Table 'arestaging' already exists
# ticker ARNC
# 1050 (42S01): Table 'arncstaging' already exists
# ticker ATVI
# 1050 (42S01): Table 'atvistaging' already exists
# ticker AVB
# 1050 (42S01): Table 'avbstaging' already exists
# ticker AVGO
# 1050 (42S01): Table 'avgostaging' already exists
# ticker AVY
# 1050 (42S01): Table 'avystaging' already exists
# ticker AWK
# 1050 (42S01): Table 'awkstaging' already exists
# ticker AXP
# 1050 (42S01): Table 'axpstaging' already exists
# ticker AYI
# 1050 (42S01): Table 'ayistaging' already exists
# ticker AZO
# 1050 (42S01): Table 'azostaging' already exists
# ticker BA
# 1050 (42S01): Table 'bastaging' already exists
# ticker BAC
# 1050 (42S01): Table 'bacstaging' already exists
# ticker BAX
# 1050 (42S01): Table 'baxstaging' already exists
# ticker BBT
# 1050 (42S01): Table 'bbtstaging' already exists
# ticker BBY
# 1050 (42S01): Table 'bbystaging' already exists
# ticker BCR
# 1050 (42S01): Table 'bcrstaging' already exists
# ticker BDX
# 1050 (42S01): Table 'bdxstaging' already exists
# ticker BEN
# 1050 (42S01): Table 'benstaging' already exists
# ticker BHF
# 1050 (42S01): Table 'bhfstaging' already exists
# ticker BHGE
# 1050 (42S01): Table 'bhgestaging' already exists
# ticker BIIB
# 1050 (42S01): Table 'biibstaging' already exists
# ticker BK
# 1050 (42S01): Table 'bkstaging' already exists
# ticker BLK
# 1050 (42S01): Table 'blkstaging' already exists
# ticker BLL
# 1050 (42S01): Table 'bllstaging' already exists
# ticker BMY
# 1050 (42S01): Table 'bmystaging' already exists
# ticker BSX
# 1050 (42S01): Table 'bsxstaging' already exists
# ticker BWA
# 1050 (42S01): Table 'bwastaging' already exists
# ticker BXP
# 1050 (42S01): Table 'bxpstaging' already exists
# ticker C
# 1050 (42S01): Table 'cstaging' already exists
# ticker CA
# 1050 (42S01): Table 'castaging' already exists
# ticker CAG
# 1050 (42S01): Table 'cagstaging' already exists
# ticker CAH
# 1050 (42S01): Table 'cahstaging' already exists
# ticker CAT
# 1050 (42S01): Table 'catstaging' already exists
# ticker CB
# 1050 (42S01): Table 'cbstaging' already exists
# ticker CBG
# 1050 (42S01): Table 'cbgstaging' already exists
# ticker CBOE
# 1050 (42S01): Table 'cboestaging' already exists
# ticker CBS
# 1050 (42S01): Table 'cbsstaging' already exists
# ticker CCI
# 1050 (42S01): Table 'ccistaging' already exists
# ticker CCL
# 1050 (42S01): Table 'cclstaging' already exists
# ticker CDNS
# 1050 (42S01): Table 'cdnsstaging' already exists
# ticker CELG
# 1050 (42S01): Table 'celgstaging' already exists
# ticker CERN
# 1050 (42S01): Table 'cernstaging' already exists
# ticker CF
# 1050 (42S01): Table 'cfstaging' already exists
# ticker CFG
# 1050 (42S01): Table 'cfgstaging' already exists
# ticker CHD
# 1050 (42S01): Table 'chdstaging' already exists
# ticker CHK
# 1050 (42S01): Table 'chkstaging' already exists
# ticker CHRW
# 1050 (42S01): Table 'chrwstaging' already exists
# ticker CHTR
# 1050 (42S01): Table 'chtrstaging' already exists
# ticker CI
# 1050 (42S01): Table 'cistaging' already exists
# ticker CINF
# 1050 (42S01): Table 'cinfstaging' already exists
# ticker CL
# 1050 (42S01): Table 'clstaging' already exists
# ticker CLX
# 1050 (42S01): Table 'clxstaging' already exists
# ticker CMA
# 1050 (42S01): Table 'cmastaging' already exists
# ticker CMCSA
# 1050 (42S01): Table 'cmcsastaging' already exists
# ticker CME
# 1050 (42S01): Table 'cmestaging' already exists
# ticker CMG
# 1050 (42S01): Table 'cmgstaging' already exists
# ticker CMI
# 1050 (42S01): Table 'cmistaging' already exists
# ticker CMS
# 1050 (42S01): Table 'cmsstaging' already exists
# ticker CNC
# 1050 (42S01): Table 'cncstaging' already exists
# ticker CNP
# 1050 (42S01): Table 'cnpstaging' already exists
# ticker COF
# 1050 (42S01): Table 'cofstaging' already exists
# ticker COG
# 1050 (42S01): Table 'cogstaging' already exists
# ticker COL
# 1050 (42S01): Table 'colstaging' already exists
# ticker COO
# 1050 (42S01): Table 'coostaging' already exists
# ticker COP
# 1050 (42S01): Table 'copstaging' already exists
# ticker COST
# 1050 (42S01): Table 'coststaging' already exists
# ticker COTY
# 1050 (42S01): Table 'cotystaging' already exists
# ticker CPB
# 1050 (42S01): Table 'cpbstaging' already exists
# ticker CRM
# 1050 (42S01): Table 'crmstaging' already exists
# ticker CSCO
# 1050 (42S01): Table 'cscostaging' already exists
# ticker CSRA
# 1050 (42S01): Table 'csrastaging' already exists
# ticker CSX
# 1050 (42S01): Table 'csxstaging' already exists
# ticker CTAS
# 1050 (42S01): Table 'ctasstaging' already exists
# ticker CTL
# 1050 (42S01): Table 'ctlstaging' already exists
# ticker CTSH
# 1050 (42S01): Table 'ctshstaging' already exists
# ticker CTXS
# 1050 (42S01): Table 'ctxsstaging' already exists
# ticker CVS
# 1050 (42S01): Table 'cvsstaging' already exists
# ticker CVX
# 1050 (42S01): Table 'cvxstaging' already exists
# ticker CXO
# 1050 (42S01): Table 'cxostaging' already exists
# ticker D
# 1050 (42S01): Table 'dstaging' already exists
# ticker DAL
# 1050 (42S01): Table 'dalstaging' already exists
# ticker DE
# 1050 (42S01): Table 'destaging' already exists
# ticker DFS
# 1050 (42S01): Table 'dfsstaging' already exists
# ticker DG
# 1050 (42S01): Table 'dgstaging' already exists
# ticker DGX
# 1050 (42S01): Table 'dgxstaging' already exists
# ticker DHI
# 1050 (42S01): Table 'dhistaging' already exists
# ticker DHR
# 1050 (42S01): Table 'dhrstaging' already exists
# ticker DIS
# 1050 (42S01): Table 'disstaging' already exists
# ticker DISCA
# 1050 (42S01): Table 'discastaging' already exists
# ticker DISCK
# 1050 (42S01): Table 'disckstaging' already exists
# ticker DISH
# 1050 (42S01): Table 'dishstaging' already exists
# ticker DLR
# 1050 (42S01): Table 'dlrstaging' already exists
# ticker DLTR
# 1050 (42S01): Table 'dltrstaging' already exists
# ticker DOV
# 1050 (42S01): Table 'dovstaging' already exists
# ticker DPS
# 1050 (42S01): Table 'dpsstaging' already exists
# ticker DRE
# 1050 (42S01): Table 'drestaging' already exists
# ticker DRI
# 1050 (42S01): Table 'dristaging' already exists
# ticker DTE
# 1050 (42S01): Table 'dtestaging' already exists
# ticker DUK
# 1050 (42S01): Table 'dukstaging' already exists
# ticker DVA
# 1050 (42S01): Table 'dvastaging' already exists
# ticker DVN
# 1050 (42S01): Table 'dvnstaging' already exists
# ticker DWDP
# 1050 (42S01): Table 'dwdpstaging' already exists
# ticker DXC
# 1050 (42S01): Table 'dxcstaging' already exists
# ticker EA
# 1050 (42S01): Table 'eastaging' already exists
# ticker EBAY
# 1050 (42S01): Table 'ebaystaging' already exists
# ticker ECL
# 1050 (42S01): Table 'eclstaging' already exists
# ticker ED
# 1050 (42S01): Table 'edstaging' already exists
# ticker EFX
# 1050 (42S01): Table 'efxstaging' already exists
# ticker EIX
# 1050 (42S01): Table 'eixstaging' already exists
# ticker EL
# 1050 (42S01): Table 'elstaging' already exists
# ticker EMN
# 1050 (42S01): Table 'emnstaging' already exists
# ticker EMR
# 1050 (42S01): Table 'emrstaging' already exists
# ticker EOG
# 1050 (42S01): Table 'eogstaging' already exists
# ticker EQIX
# 1050 (42S01): Table 'eqixstaging' already exists
# ticker EQR
# 1050 (42S01): Table 'eqrstaging' already exists
# ticker EQT
# 1050 (42S01): Table 'eqtstaging' already exists
# ticker ES
# 1050 (42S01): Table 'esstaging' already exists
# ticker ESRX
# 1050 (42S01): Table 'esrxstaging' already exists
# ticker ESS
# 1050 (42S01): Table 'essstaging' already exists
# ticker ETFC
# 1050 (42S01): Table 'etfcstaging' already exists
# ticker ETN
# 1050 (42S01): Table 'etnstaging' already exists
# ticker ETR
# 1050 (42S01): Table 'etrstaging' already exists
# ticker EVHC
# 1050 (42S01): Table 'evhcstaging' already exists
# ticker EW
# 1050 (42S01): Table 'ewstaging' already exists
# ticker EXC
# 1050 (42S01): Table 'excstaging' already exists
# ticker EXPD
# 1050 (42S01): Table 'expdstaging' already exists
# ticker EXPE
# 1050 (42S01): Table 'expestaging' already exists
# ticker EXR
# 1050 (42S01): Table 'exrstaging' already exists
# ticker F
# 1050 (42S01): Table 'fstaging' already exists
# ticker FAST
# 1050 (42S01): Table 'faststaging' already exists
# ticker FB
# 1050 (42S01): Table 'fbstaging' already exists
# ticker FBHS
# 1050 (42S01): Table 'fbhsstaging' already exists
# ticker FCX
# 1050 (42S01): Table 'fcxstaging' already exists
# ticker FDX
# 1050 (42S01): Table 'fdxstaging' already exists
# ticker FE
# 1050 (42S01): Table 'festaging' already exists
# ticker FFIV
# 1050 (42S01): Table 'ffivstaging' already exists
# ticker FIS
# 1050 (42S01): Table 'fisstaging' already exists
# ticker FISV
# 1050 (42S01): Table 'fisvstaging' already exists
# ticker FITB
# 1050 (42S01): Table 'fitbstaging' already exists
# ticker FL
# 1050 (42S01): Table 'flstaging' already exists
# ticker FLIR
# 1050 (42S01): Table 'flirstaging' already exists
# ticker FLR
# 1050 (42S01): Table 'flrstaging' already exists
# ticker FLS
# 1050 (42S01): Table 'flsstaging' already exists
# ticker FMC
# 1050 (42S01): Table 'fmcstaging' already exists
# ticker FOX
# 1050 (42S01): Table 'foxstaging' already exists
# ticker FOXA
# 1050 (42S01): Table 'foxastaging' already exists
# ticker FRT
# 1050 (42S01): Table 'frtstaging' already exists
# ticker FTI
# 1050 (42S01): Table 'ftistaging' already exists
# ticker FTV
# 1050 (42S01): Table 'ftvstaging' already exists
# ticker GD
# 1050 (42S01): Table 'gdstaging' already exists
# ticker GE
# 1050 (42S01): Table 'gestaging' already exists
# ticker GGP
# 1050 (42S01): Table 'ggpstaging' already exists
# ticker GILD
# 1050 (42S01): Table 'gildstaging' already exists
# ticker GIS
# 1050 (42S01): Table 'gisstaging' already exists
# ticker GLW
# 1050 (42S01): Table 'glwstaging' already exists
# ticker GM
# 1050 (42S01): Table 'gmstaging' already exists
# ticker GOOG
# 1050 (42S01): Table 'googstaging' already exists
# ticker GOOGL
# 1050 (42S01): Table 'googlstaging' already exists
# ticker GPC
# 1050 (42S01): Table 'gpcstaging' already exists
# ticker GPN
# 1050 (42S01): Table 'gpnstaging' already exists
# ticker GPS
# 1050 (42S01): Table 'gpsstaging' already exists
# ticker GRMN
# 1050 (42S01): Table 'grmnstaging' already exists
# ticker GS
# 1050 (42S01): Table 'gsstaging' already exists
# ticker GT
# 1050 (42S01): Table 'gtstaging' already exists
# ticker GWW
# 1050 (42S01): Table 'gwwstaging' already exists
# ticker HAL
# 1050 (42S01): Table 'halstaging' already exists
# ticker HAS
# 1050 (42S01): Table 'hasstaging' already exists
# ticker HBAN
# 1050 (42S01): Table 'hbanstaging' already exists
# ticker HBI
# 1050 (42S01): Table 'hbistaging' already exists
# ticker HCA
# 1050 (42S01): Table 'hcastaging' already exists
# ticker HCN
# 1050 (42S01): Table 'hcnstaging' already exists
# ticker HCP
# 1050 (42S01): Table 'hcpstaging' already exists
# ticker HD
# 1050 (42S01): Table 'hdstaging' already exists
# ticker HES
# 1050 (42S01): Table 'hesstaging' already exists
# ticker HIG
# 1050 (42S01): Table 'higstaging' already exists
# ticker HLT
# 1050 (42S01): Table 'hltstaging' already exists
# ticker HOG
# 1050 (42S01): Table 'hogstaging' already exists
# ticker HOLX
# 1050 (42S01): Table 'holxstaging' already exists
# ticker HON
# 1050 (42S01): Table 'honstaging' already exists
# ticker HP
# 1050 (42S01): Table 'hpstaging' already exists
# ticker HPE
# 1050 (42S01): Table 'hpestaging' already exists
# ticker HPQ
# 1050 (42S01): Table 'hpqstaging' already exists
# ticker HRB
# 1050 (42S01): Table 'hrbstaging' already exists
# ticker HRL
# 1050 (42S01): Table 'hrlstaging' already exists
# ticker HRS
# 1050 (42S01): Table 'hrsstaging' already exists
# ticker HSIC
# 1050 (42S01): Table 'hsicstaging' already exists
# ticker HST
# 1050 (42S01): Table 'hststaging' already exists
# ticker HSY
# 1050 (42S01): Table 'hsystaging' already exists
# ticker HUM
# 1050 (42S01): Table 'humstaging' already exists
# ticker IBM
# 1050 (42S01): Table 'ibmstaging' already exists
# ticker ICE
# 1050 (42S01): Table 'icestaging' already exists
# ticker IDXX
# 1050 (42S01): Table 'idxxstaging' already exists
# ticker IFF
# 1050 (42S01): Table 'iffstaging' already exists
# ticker ILMN
# 1050 (42S01): Table 'ilmnstaging' already exists
# ticker INCY
# 1050 (42S01): Table 'incystaging' already exists
# ticker INFO
# 1050 (42S01): Table 'infostaging' already exists
# ticker INTC
# 1050 (42S01): Table 'intcstaging' already exists
# ticker INTU
# 1050 (42S01): Table 'intustaging' already exists
# ticker IP
# 1050 (42S01): Table 'ipstaging' already exists
# ticker IPG
# 1050 (42S01): Table 'ipgstaging' already exists
# ticker IQV
# 1050 (42S01): Table 'iqvstaging' already exists
# ticker IR
# 1050 (42S01): Table 'irstaging' already exists
# ticker IRM
# 1050 (42S01): Table 'irmstaging' already exists
# ticker ISRG
# 1050 (42S01): Table 'isrgstaging' already exists
# ticker IT
# 1050 (42S01): Table 'itstaging' already exists
# ticker ITW
# 1050 (42S01): Table 'itwstaging' already exists
# ticker IVZ
# 1050 (42S01): Table 'ivzstaging' already exists
# ticker JBHT
# 1050 (42S01): Table 'jbhtstaging' already exists
# ticker JCI
# 1050 (42S01): Table 'jcistaging' already exists
# ticker JEC
# 1050 (42S01): Table 'jecstaging' already exists
# ticker JNJ
# 1050 (42S01): Table 'jnjstaging' already exists
# ticker JNPR
# 1050 (42S01): Table 'jnprstaging' already exists
# ticker JPM
# 1050 (42S01): Table 'jpmstaging' already exists
# ticker JWN
# 1050 (42S01): Table 'jwnstaging' already exists
# ticker K
# 1050 (42S01): Table 'kstaging' already exists
# ticker KEY
# 1050 (42S01): Table 'keystaging' already exists
# ticker KHC
# 1050 (42S01): Table 'khcstaging' already exists
# ticker KIM
# 1050 (42S01): Table 'kimstaging' already exists
# ticker KLAC
# 1050 (42S01): Table 'klacstaging' already exists
# ticker KMB
# 1050 (42S01): Table 'kmbstaging' already exists
# ticker KMI
# 1050 (42S01): Table 'kmistaging' already exists
# ticker KMX
# 1050 (42S01): Table 'kmxstaging' already exists
# ticker KO
# 1050 (42S01): Table 'kostaging' already exists
# ticker KORS
# 1050 (42S01): Table 'korsstaging' already exists
# ticker KR
# 1050 (42S01): Table 'krstaging' already exists
# ticker KSS
# 1050 (42S01): Table 'kssstaging' already exists
# ticker KSU
# 1050 (42S01): Table 'ksustaging' already exists
# ticker L
# 1050 (42S01): Table 'lstaging' already exists
# ticker LB
# 1050 (42S01): Table 'lbstaging' already exists
# ticker LEG
# 1050 (42S01): Table 'legstaging' already exists
# ticker LEN
# 1050 (42S01): Table 'lenstaging' already exists
# ticker LH
# 1050 (42S01): Table 'lhstaging' already exists
# ticker LKQ
# 1050 (42S01): Table 'lkqstaging' already exists
# ticker LLL
# 1050 (42S01): Table 'lllstaging' already exists
# ticker LLY
# 1050 (42S01): Table 'llystaging' already exists
# ticker LMT
# 1050 (42S01): Table 'lmtstaging' already exists
# ticker LNC
# 1050 (42S01): Table 'lncstaging' already exists
# ticker LNT
# 1050 (42S01): Table 'lntstaging' already exists
# ticker LOW
# 1050 (42S01): Table 'lowstaging' already exists
# ticker LRCX
# 1050 (42S01): Table 'lrcxstaging' already exists
# ticker LUK
# 1050 (42S01): Table 'lukstaging' already exists
# ticker LUV
# 1050 (42S01): Table 'luvstaging' already exists
# ticker LYB
# 1050 (42S01): Table 'lybstaging' already exists
# ticker M
# 1050 (42S01): Table 'mstaging' already exists
# ticker MA
# 1050 (42S01): Table 'mastaging' already exists
# ticker MAA
# 1050 (42S01): Table 'maastaging' already exists
# ticker MAC
# 1050 (42S01): Table 'macstaging' already exists
# ticker MAR
# 1050 (42S01): Table 'marstaging' already exists
# ticker MAS
# 1050 (42S01): Table 'masstaging' already exists
# ticker MAT
# 1050 (42S01): Table 'matstaging' already exists
# ticker MCD
# 1050 (42S01): Table 'mcdstaging' already exists
# ticker MCHP
# 1050 (42S01): Table 'mchpstaging' already exists
# ticker MCK
# 1050 (42S01): Table 'mckstaging' already exists
# ticker MCO
# 1050 (42S01): Table 'mcostaging' already exists
# ticker MDLZ
# 1050 (42S01): Table 'mdlzstaging' already exists
# ticker MDT
# 1050 (42S01): Table 'mdtstaging' already exists
# ticker MET
# 1050 (42S01): Table 'metstaging' already exists
# ticker MGM
# 1050 (42S01): Table 'mgmstaging' already exists
# ticker MHK
# 1050 (42S01): Table 'mhkstaging' already exists
# ticker MKC
# 1050 (42S01): Table 'mkcstaging' already exists
# ticker MLM
# 1050 (42S01): Table 'mlmstaging' already exists
# ticker MMC
# 1050 (42S01): Table 'mmcstaging' already exists
# ticker MMM
# 1050 (42S01): Table 'mmmstaging' already exists
# ticker MNST
# 1050 (42S01): Table 'mnststaging' already exists
# ticker MO
# 1050 (42S01): Table 'mostaging' already exists
# ticker MON
# 1050 (42S01): Table 'monstaging' already exists
# ticker MOS
# 1050 (42S01): Table 'mosstaging' already exists
# ticker MPC
# 1050 (42S01): Table 'mpcstaging' already exists
# ticker MRK
# 1050 (42S01): Table 'mrkstaging' already exists
# ticker MRO
# 1050 (42S01): Table 'mrostaging' already exists
# ticker MS
# insert row
# load file stock_dfs/MS.csv into MSStaging
# load file stock_dfs/MS.csv into database
# ticker MSFT
# 1050 (42S01): Table 'msftstaging' already exists
# ticker MSI
# 1050 (42S01): Table 'msistaging' already exists
# ticker MTB
# 1050 (42S01): Table 'mtbstaging' already exists
# ticker MTD
# 1050 (42S01): Table 'mtdstaging' already exists
# ticker MU
# 1050 (42S01): Table 'mustaging' already exists
# ticker MYL
# 1050 (42S01): Table 'mylstaging' already exists
# ticker NAVI
# insert row
# load file stock_dfs/NAVI.csv into NAVIStaging
# load file stock_dfs/NAVI.csv into database
# ticker NBL
# insert row
# load file stock_dfs/NBL.csv into NBLStaging
# load file stock_dfs/NBL.csv into database
# ticker NCLH
# insert row
# load file stock_dfs/NCLH.csv into NCLHStaging
# load file stock_dfs/NCLH.csv into database
# ticker NDAQ
# 1050 (42S01): Table 'ndaqstaging' already exists
# ticker NEE
# 1050 (42S01): Table 'neestaging' already exists
# ticker NEM
# 1050 (42S01): Table 'nemstaging' already exists
# ticker NFLX
# 1050 (42S01): Table 'nflxstaging' already exists
# ticker NFX
# 1050 (42S01): Table 'nfxstaging' already exists
# ticker NI
# 1050 (42S01): Table 'nistaging' already exists
# ticker NKE
# 1050 (42S01): Table 'nkestaging' already exists
# ticker NLSN
# 1050 (42S01): Table 'nlsnstaging' already exists
# ticker NOC
# 1050 (42S01): Table 'nocstaging' already exists
# ticker NOV
# 1050 (42S01): Table 'novstaging' already exists
# ticker NRG
# 1050 (42S01): Table 'nrgstaging' already exists
# ticker NSC
# 1050 (42S01): Table 'nscstaging' already exists
# ticker NTAP
# 1050 (42S01): Table 'ntapstaging' already exists
# ticker NTRS
# 1050 (42S01): Table 'ntrsstaging' already exists
# ticker NUE
# 1050 (42S01): Table 'nuestaging' already exists
# ticker NVDA
# 1050 (42S01): Table 'nvdastaging' already exists
# ticker NWL
# 1050 (42S01): Table 'nwlstaging' already exists
# ticker NWS
# 1050 (42S01): Table 'nwsstaging' already exists
# ticker NWSA
# 1050 (42S01): Table 'nwsastaging' already exists
# ticker O
# 1050 (42S01): Table 'ostaging' already exists
# ticker OKE
# 1050 (42S01): Table 'okestaging' already exists
# ticker OMC
# insert row
# load file stock_dfs/OMC.csv into OMCStaging
# load file stock_dfs/OMC.csv into database
# ticker ORCL
# 1050 (42S01): Table 'orclstaging' already exists
# ticker ORLY
# insert row
# load file stock_dfs/ORLY.csv into ORLYStaging
# load file stock_dfs/ORLY.csv into database
# ticker OXY
# insert row
# load file stock_dfs/OXY.csv into OXYStaging
# load file stock_dfs/OXY.csv into database
# ticker PAYX
# 1050 (42S01): Table 'payxstaging' already exists
# ticker PBCT
# 1050 (42S01): Table 'pbctstaging' already exists
# ticker PCAR
# insert row
# load file stock_dfs/PCAR.csv into PCARStaging
# load file stock_dfs/PCAR.csv into database
# ticker PCG
# 1050 (42S01): Table 'pcgstaging' already exists
# ticker PCLN
# 1050 (42S01): Table 'pclnstaging' already exists
# ticker PDCO
# 1050 (42S01): Table 'pdcostaging' already exists
# ticker PEG
# insert row
# load file stock_dfs/PEG.csv into PEGStaging
# load file stock_dfs/PEG.csv into database
# ticker PEP
# 1050 (42S01): Table 'pepstaging' already exists
# ticker PFE
# 1050 (42S01): Table 'pfestaging' already exists
# ticker PFG
# 1050 (42S01): Table 'pfgstaging' already exists
# ticker PG
# 1050 (42S01): Table 'pgstaging' already exists
# ticker PGR
# 1050 (42S01): Table 'pgrstaging' already exists
# ticker PH
# 1050 (42S01): Table 'phstaging' already exists
# ticker PHM
# 1050 (42S01): Table 'phmstaging' already exists
# ticker PKG
# 1050 (42S01): Table 'pkgstaging' already exists
# ticker PLD
# 1050 (42S01): Table 'pldstaging' already exists
# ticker PM
# 1050 (42S01): Table 'pmstaging' already exists
# ticker PNC
# 1050 (42S01): Table 'pncstaging' already exists
# ticker PNR
# insert row
# load file stock_dfs/PNR.csv into PNRStaging
# load file stock_dfs/PNR.csv into database
# ticker PPG
# 1050 (42S01): Table 'ppgstaging' already exists
# ticker PPL
# insert row
# load file stock_dfs/PPL.csv into PPLStaging
# load file stock_dfs/PPL.csv into database
# ticker PRGO
# 1050 (42S01): Table 'prgostaging' already exists
# ticker PRU
# 1050 (42S01): Table 'prustaging' already exists
# ticker PSA
# 1050 (42S01): Table 'psastaging' already exists
# ticker PSX
# 1050 (42S01): Table 'psxstaging' already exists
# ticker PVH
# insert row
# load file stock_dfs/PVH.csv into PVHStaging
# load file stock_dfs/PVH.csv into database
# ticker PWR
# 1050 (42S01): Table 'pwrstaging' already exists
# ticker PX
# 1050 (42S01): Table 'pxstaging' already exists
# ticker PXD
# 1050 (42S01): Table 'pxdstaging' already exists
# ticker PYPL
# 1050 (42S01): Table 'pyplstaging' already exists
# ticker QCOM
# insert row
# load file stock_dfs/QCOM.csv into QCOMStaging
# load file stock_dfs/QCOM.csv into database
# ticker QRVO
# 1050 (42S01): Table 'qrvostaging' already exists
# ticker RCL
# 1050 (42S01): Table 'rclstaging' already exists
# ticker RE
# 1050 (42S01): Table 'restaging' already exists
# ticker REG
# 1050 (42S01): Table 'regstaging' already exists
# ticker REGN
# 1050 (42S01): Table 'regnstaging' already exists
# ticker RF
# 1050 (42S01): Table 'rfstaging' already exists
# ticker RHI
# 1050 (42S01): Table 'rhistaging' already exists
# ticker RHT
# 1050 (42S01): Table 'rhtstaging' already exists
# ticker RJF
# 1050 (42S01): Table 'rjfstaging' already exists
# ticker RL
# 1050 (42S01): Table 'rlstaging' already exists
# ticker RMD
# 1050 (42S01): Table 'rmdstaging' already exists
# ticker ROK
# 1050 (42S01): Table 'rokstaging' already exists
# ticker ROP
# insert row
# load file stock_dfs/ROP.csv into ROPStaging
# load file stock_dfs/ROP.csv into database
# ticker ROST
# 1050 (42S01): Table 'roststaging' already exists
# ticker RRC
# 1050 (42S01): Table 'rrcstaging' already exists
# ticker RSG
# 1050 (42S01): Table 'rsgstaging' already exists
# ticker RTN
# 1050 (42S01): Table 'rtnstaging' already exists
# ticker SBAC
# 1050 (42S01): Table 'sbacstaging' already exists
# ticker SBUX
# 1050 (42S01): Table 'sbuxstaging' already exists
# ticker SCHW
# 1050 (42S01): Table 'schwstaging' already exists
# ticker SEE
# 1050 (42S01): Table 'seestaging' already exists
# ticker SHW
# 1050 (42S01): Table 'shwstaging' already exists
# ticker SIG
# 1050 (42S01): Table 'sigstaging' already exists
# ticker SJM
# 1050 (42S01): Table 'sjmstaging' already exists
# ticker SLB
# 1050 (42S01): Table 'slbstaging' already exists
# ticker SLG
# 1050 (42S01): Table 'slgstaging' already exists
# ticker SNA
# 1050 (42S01): Table 'snastaging' already exists
# ticker SNI
# 1050 (42S01): Table 'snistaging' already exists
# ticker SNPS
# 1050 (42S01): Table 'snpsstaging' already exists
# ticker SO
# insert row
# load file stock_dfs/SO.csv into SOStaging
# load file stock_dfs/SO.csv into database
# ticker SPG
# 1050 (42S01): Table 'spgstaging' already exists
# ticker SPGI
# 1050 (42S01): Table 'spgistaging' already exists
# ticker SRCL
# 1050 (42S01): Table 'srclstaging' already exists
# ticker SRE
# 1050 (42S01): Table 'srestaging' already exists
# ticker STI
# 1050 (42S01): Table 'stistaging' already exists
# ticker STT
# 1050 (42S01): Table 'sttstaging' already exists
# ticker STX
# 1050 (42S01): Table 'stxstaging' already exists
# ticker STZ
# 1050 (42S01): Table 'stzstaging' already exists
# ticker SWK
# 1050 (42S01): Table 'swkstaging' already exists
# ticker SWKS
# 1050 (42S01): Table 'swksstaging' already exists
# ticker SYF
# 1050 (42S01): Table 'syfstaging' already exists
# ticker SYK
# insert row
# load file stock_dfs/SYK.csv into SYKStaging
# load file stock_dfs/SYK.csv into database
# ticker SYMC
# 1050 (42S01): Table 'symcstaging' already exists
# ticker SYY
# insert row
# load file stock_dfs/SYY.csv into SYYStaging
# load file stock_dfs/SYY.csv into database
# ticker T
# 1050 (42S01): Table 'tstaging' already exists
# ticker TAP
# 1050 (42S01): Table 'tapstaging' already exists
# ticker TDG
# insert row
# load file stock_dfs/TDG.csv into TDGStaging
# load file stock_dfs/TDG.csv into database
# ticker TEL
# 1050 (42S01): Table 'telstaging' already exists
# ticker TGT
# insert row
# load file stock_dfs/TGT.csv into TGTStaging
# load file stock_dfs/TGT.csv into database
# ticker TIF
# 1050 (42S01): Table 'tifstaging' already exists
# ticker TJX
# 1050 (42S01): Table 'tjxstaging' already exists
# ticker TMK
# 1050 (42S01): Table 'tmkstaging' already exists
# ticker TMO
# 1050 (42S01): Table 'tmostaging' already exists
# ticker TPR
# 1050 (42S01): Table 'tprstaging' already exists
# ticker TRIP
# 1050 (42S01): Table 'tripstaging' already exists
# ticker TROW
# insert row
# load file stock_dfs/TROW.csv into TROWStaging
# load file stock_dfs/TROW.csv into database
# ticker TRV
# 1050 (42S01): Table 'trvstaging' already exists
# ticker TSCO
# 1050 (42S01): Table 'tscostaging' already exists
# ticker TSN
# 1050 (42S01): Table 'tsnstaging' already exists
# ticker TSS
# insert row
# load file stock_dfs/TSS.csv into TSSStaging
# load file stock_dfs/TSS.csv into database
# ticker TWX
# 1050 (42S01): Table 'twxstaging' already exists
# ticker TXN
# 1050 (42S01): Table 'txnstaging' already exists
# ticker TXT
# insert row
# load file stock_dfs/TXT.csv into TXTStaging
# load file stock_dfs/TXT.csv into database
# ticker UA
# 1050 (42S01): Table 'uastaging' already exists
# ticker UAA
# 1050 (42S01): Table 'uaastaging' already exists
# ticker UAL
# 1050 (42S01): Table 'ualstaging' already exists
# ticker UDR
# 1050 (42S01): Table 'udrstaging' already exists
# ticker UHS
# 1050 (42S01): Table 'uhsstaging' already exists
# ticker ULTA
# 1050 (42S01): Table 'ultastaging' already exists
# ticker UNH
# 1050 (42S01): Table 'unhstaging' already exists
# ticker UNM
# 1050 (42S01): Table 'unmstaging' already exists
# ticker UNP
# insert row
# load file stock_dfs/UNP.csv into UNPStaging
# load file stock_dfs/UNP.csv into database
# ticker UPS
# 1050 (42S01): Table 'upsstaging' already exists
# ticker URI
# 1050 (42S01): Table 'uristaging' already exists
# ticker UTX
# 1050 (42S01): Table 'utxstaging' already exists
# ticker V
# 1050 (42S01): Table 'vstaging' already exists
# ticker VAR
# 1050 (42S01): Table 'varstaging' already exists
# ticker VFC
# 1050 (42S01): Table 'vfcstaging' already exists
# ticker VIAB
# 1050 (42S01): Table 'viabstaging' already exists
# ticker VLO
# 1050 (42S01): Table 'vlostaging' already exists
# ticker VMC
# 1050 (42S01): Table 'vmcstaging' already exists
# ticker VNO
# 1050 (42S01): Table 'vnostaging' already exists
# ticker VRSK
# 1050 (42S01): Table 'vrskstaging' already exists
# ticker VRSN
# 1050 (42S01): Table 'vrsnstaging' already exists
# ticker VRTX
# 1050 (42S01): Table 'vrtxstaging' already exists
# ticker VTR
# insert row
# load file stock_dfs/VTR.csv into VTRStaging
# load file stock_dfs/VTR.csv into database
# ticker VZ
# 1050 (42S01): Table 'vzstaging' already exists
# ticker WAT
# 1050 (42S01): Table 'watstaging' already exists
# ticker WBA
# 1050 (42S01): Table 'wbastaging' already exists
# ticker WDC
# 1050 (42S01): Table 'wdcstaging' already exists
# ticker WEC
# 1050 (42S01): Table 'wecstaging' already exists
# ticker WFC
# 1050 (42S01): Table 'wfcstaging' already exists
# ticker WHR
# 1050 (42S01): Table 'whrstaging' already exists
# ticker WLTW
# 1050 (42S01): Table 'wltwstaging' already exists
# ticker WM
# 1050 (42S01): Table 'wmstaging' already exists
# ticker WMB
# 1050 (42S01): Table 'wmbstaging' already exists
# ticker WMT
# 1050 (42S01): Table 'wmtstaging' already exists
# ticker WRK
# insert row
# load file stock_dfs/WRK.csv into WRKStaging
# load file stock_dfs/WRK.csv into database
# ticker WU
# 1050 (42S01): Table 'wustaging' already exists
# ticker WY
# 1050 (42S01): Table 'wystaging' already exists
# ticker WYN
# insert row
# load file stock_dfs/WYN.csv into WYNStaging
# load file stock_dfs/WYN.csv into database
# ticker WYNN
# 1050 (42S01): Table 'wynnstaging' already exists
# ticker XEC
# 1050 (42S01): Table 'xecstaging' already exists
# ticker XEL
# 1050 (42S01): Table 'xelstaging' already exists
# ticker XL
# 1050 (42S01): Table 'xlstaging' already exists
# ticker XLNX
# 1050 (42S01): Table 'xlnxstaging' already exists
# ticker XOM
# 1050 (42S01): Table 'xomstaging' already exists
# ticker XRAY
# 1050 (42S01): Table 'xraystaging' already exists
# ticker XRX
# 1050 (42S01): Table 'xrxstaging' already exists
# ticker XYL
# 1050 (42S01): Table 'xylstaging' already exists
# ticker YUM
# 1050 (42S01): Table 'yumstaging' already exists
# ticker ZBH
# insert row
# load file stock_dfs/ZBH.csv into ZBHStaging
# load file stock_dfs/ZBH.csv into database
# ticker ZION
# 1050 (42S01): Table 'zionstaging' already exists
# ticker ZTS
# 1050 (42S01): Table 'ztsstaging' already exists
